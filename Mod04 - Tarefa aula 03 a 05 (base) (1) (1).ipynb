# %% [markdown]
# ## Exercício 1: Vestibular
#
# Considere que a os dados gerados na célula abaixo contêm o número de acertos de 100 alunos em um vestibular para um curso de exatas, divididas pelos respectivos assuntos. Considere que cada assunto possui um número de questões conforme a tabela abaixo:
#
# | assunto | número de questões |
# |:---:|:---:|
# | Matemática | 24 |
# | Português | 18 |
# | Geografia | 8 |
# | Inglês | 8 |
# | História | 8 |
# | Física | 12 |
# | Química | 12 |
#
# Usando os comandos de operações com DataFrames que você aprendeu na Aula 03, calcule:
#
# 1. (operações com escalar) Calcule o percentual de acerto dos alunos por assunto.
# 2. (operações entre *DataFrames) Calcule o total de acertos de cada aluno.
# 3. Calcule o porcentual geral de cada aluno.
# 4. Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior que 45?

# %%
import pandas as pd
import numpy as np

np.random.seed(42)
df_mat = pd.DataFrame(np.random.randint(24, size=(100, 1)), columns=['Qt_acertos'])

df_por = pd.DataFrame(np.random.randint(18, size=(100, 1)), columns=['Qt_acertos'])

df_geo = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_ing = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_his = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_fis = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

df_qui = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

# %%
# 1) Seu código aqui
print(f'Matemática: {(df_mat["Qt_acertos"].sum() / (24 * 100)):.2%}')
print(f'Português: {(df_por["Qt_acertos"].sum() / (18 * 100)):.2%}')
print(f'Geografia: {(df_geo["Qt_acertos"].sum() / (8 * 100)):.2%}')
print(f'Inglês: {(df_ing["Qt_acertos"].sum() / (8 * 100)):.2%}')
print(f'História: {(df_his["Qt_acertos"].sum() / (8 * 100)):.2%}')
print(f'Física: {(df_fis["Qt_acertos"].sum() / (12 * 100)):.2%}')
print(f'Química: {(df_qui["Qt_acertos"].sum() / (12 * 100)):.2%}')

pc_mat = df_mat / 24
pc_por = df_por / 18
pc_geo = df_geo /  8
pc_ing = df_ing /  8
pc_his = df_his /  8
pc_fis = df_fis /  8
pc_qui = df_qui /  8
# Out:
# Matemática: 49.38%
# Português: 40.17%
# Geografia: 42.00%
# Inglês: 47.62%
# História: 45.00%
# Física: 44.33%
# Química: 45.25%

# %%
# 2) Seu código aqui
df = pd.DataFrame()
df['Matemática'] = df_mat["Qt_acertos"]
df['Português'] = df_por["Qt_acertos"]
df['Geografia'] = df_geo["Qt_acertos"]
df['Inglês'] = df_ing["Qt_acertos"]
df['História'] = df_his["Qt_acertos"]
df['Física'] = df_fis["Qt_acertos"]
df['Química'] = df_qui["Qt_acertos"]
df['Total_Acertos'] = (df['Matemática'] + df['Português'] +
                      df['Geografia'] + df['Inglês'] +
                      df['História'] + df['Física'] + 
                      df['Química'])
df.head(10)
# Out:
#    Matemática  Português  Geografia  Inglês  História  Física  Química  \
# 0           6          7          7       3         1       8        3
# 1          19         10          0       0         0      11        8
# 2          14         16          0       5         7       4        4
# 3          10          7          3       4         0       0        8
# 4           7          2          2       7         0       9        3
# 5          20          2          5       3         2       9        9
# 6           6          0          7       7         5       0        4
# 7          18          4          4       7         7       1        8
# 8          22          9          2       7         6       5        7
# 9          10          6          3       6         4       8        2
#
#    Total_Acertos
# 0             35
# 1             48
# 2             50
# 3             32
# 4             30
# 5             50
# 6             29
# 7             49
# 8             58
# 9             39

# %%
# 3) Seu código aqui
Qt_acertos_total = 24 + 18 + 8 + 8 + 8 + 12 + 12
df['Total_Acertos_%'] = round((df['Total_Acertos'] / 90 * 100), 2)
df.head(10)
# Out:
#    Matemática  Português  Geografia  Inglês  História  Física  Química  \
# 0           6          7          7       3         1       8        3
# 1          19         10          0       0         0      11        8
# 2          14         16          0       5         7       4        4
# 3          10          7          3       4         0       0        8
# 4           7          2          2       7         0       9        3
# 5          20          2          5       3         2       9        9
# 6           6          0          7       7         5       0        4
# 7          18          4          4       7         7       1        8
# 8          22          9          2       7         6       5        7
# 9          10          6          3       6         4       8        2
#
#    Total_Acertos  Total_Acertos_%
# 0             35            38.89
# 1             48            53.33
# 2             50            55.56
# 3             32            35.56
# 4             30            33.33
# 5             50            55.56
# 6             29            32.22
# 7             49            54.44
# 8             58            64.44
# 9             39            43.33

# %%
# 4) Seu código aqui
df[df['Total_Acertos'] > 45].index.nunique()
# Out:
# 31

# %% [markdown]
# ## 2) Vestibular II
#
# Ainda sobre o mesmo banco de dados:
#
# 1. Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. Monte um novo *DataFrame* com os alunos desqualificados por este critério.
# 2. Quantos são esses alunos?
# 3. Qual a média desses alunos em história e geografia?
# 4. Monte um *DataFrame* com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.

# %%
# seu código aqui
# 1. Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado.
# Monte um novo DataFrame com os alunos desqualificados por este critério

df_eliminados = df[ (df['Matemática'] == 0) |
                         (df['Física'] == 0) |
                         (df['Química'] == 0) ]
df_eliminados.head(5)
# Out:
#     Matemática  Português  Geografia  Inglês  História  Física  Química  \
# 3           10          7          3       4         0       0        8
# 6            6          0          7       7         5       0        4
# 10          10          8          3       2         1       7        0
# 12          20          8          3       7         1       0        3
# 14           7         11          1       7         1       4        0
#
#     Total_Acertos  Total_Acertos_%
# 3              32            35.56
# 6              29            32.22
# 10             31            34.44
# 12             42            46.67
# 14             31            34.44

# %%
# 2. Quantos são esses alunos?
df_eliminados.index.nunique()
# Out:
# 23

# %%
# 3. Qual a média desses alunos em história e geografia?
print(f'Média História: {df_eliminados["História"].mean():.2}')
print(f'Média Geografia: {df_eliminados["Geografia"].mean():.2}')
# Out:
# Média História: 3.4
# Média Geografia: 3.2

# %%
# 4. Monte um DataFrame com os alunos que passaram para a segunda fase.
# Repare que estes alunos não podem ter sido desqualificados
df_eliminados = df[ (df['Matemática'] != 0) &
                    (df['Física'] != 0) &
                    (df['Química'] != 0)]
df_eliminados
# Out:
#     Matemática  Português  Geografia  Inglês  História  Física  Química  \
# 0            6          7          7       3         1       8        3
# 1           19         10          0       0         0      11        8
# 2           14         16          0       5         7       4        4
# 4            7          2          2       7         0       9        3
# 5           20          2          5       3         2       9        9
# ..         ...        ...        ...     ...       ...     ...      ...
# 93          12         16          5       5         6       6        6
# 95           6          4          7       1         4       9        3
# 96           8          1          4       6         1       4        3
# 97          23          5          0       2         4       1        5
# 99          11         15          0       1         6       7        2
#
#     Total_Acertos  Total_Acertos_%
# 0              35            38.89
# 1              48            53.33
# 2              50            55.56
# 4              30            33.33
# 5              50            55.56
# ..            ...              ...
# 93             56            62.22
# 95             34            37.78
# 96             27            30.00
# 97             40            44.44
# 99             42            46.67
#
# [77 rows x 9 columns]

# %% [markdown]
# ## 3) Vacinações no Acre
# Vamos trabalhar agora com a base de vacinações no Acre. Para facilitar a sua vida, copiamos o link do arquivo na célula abaixo.
#
# 1. Quantas vacinas estão registradas nessa base?
# 2. Quantos pacientes foram vacinados? (considere um paciente para cada valor único de ```paciente_id```)
# 3. Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. Receba os valores do campo com o método ```.unique()```.
# 4. Quantos pacientes com menos de 18 anos foram vacinados?
# 5. Quantos estabelecimentos aplicaram vacina no Acre?
#
#
# **OBS:** O portal do DATASUS pode apresentar instabilidades, retornando um erro na segunda célula abaixo. Por este motivo está disponível uma base estática, que se for baixada para o seu *working directory* pode ser lida com este comando: ```df = pd.read_csv('registros de vacinacao covid ACRE.csv', sep=';')```.
#
# **OBS2:** Para saber qual é o seu working directory, rode no jupyter: ```!pwd```.

# %%
# arquivo = 'https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/uf/2021-05-23/uf%3DAC/part-00000-63e5bee2-3684-4286-b709-7fe85483b04e.c000.csv'
# link:'https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SIPNI/COVID/uf/uf%3DAC/part-00000-ef18674d-d3c2-4810-bb81-0e2290124cce.c000.csv'

# %%
# 1) Sua solução aqui
vacAcre = pd.read_csv('https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SIPNI/COVID/uf/uf%3DAC/part-00000-ef18674d-d3c2-4810-bb81-0e2290124cce.c000.csv', sep=';')
vacAcre.head(5)
# df = pd.read_csv(arquivo, sep=';')
# Out:
# C:\Users\perey\AppData\Local\Temp\ipykernel_23112\2255458574.py:2: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   vacAcre = pd.read_csv('https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SIPNI/COVID/uf/uf%3DAC/part-00000-ef18674d-d3c2-4810-bb81-0e2290124cce.c000.csv', sep=';')
#                                  document_id  \
# 0  2129beab-a813-412e-adf1-02878b427b81-i0b0
# 1  5fb3b4b8-1035-489c-bcfb-2eef4a3dbf6e-i0b0
# 2  406d10ac-6eea-4889-bd70-08f5cfc91698-i0b0
# 3  5fc5171d-fcca-4777-9c38-7009357bf486-i0b0
# 4  9c40bdcd-78df-42a2-baba-df6b6d8d2b40-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  7f22d009fc79c0e65a1a4c51542da4bbb88fb51bb631a9...              43
# 1  f04fa961fb64257ae4ab24f5ee31c22534a68c0bd4bf95...              14
# 2  163928d20b579463c9313f1d58ce575cdd585f8afa3c1a...              33
# 3  0abd1dfae4881cfa25c8cd985381ee416755b38f646d4b...              35
# 4  ed43984d7c86535e9493f652ae24f5c13049b6d497766e...              12
#
#   paciente_dataNascimento paciente_enumSexoBiologico  paciente_racaCor_codigo  \
# 0              1978-02-15                          F                        4
# 1              2007-07-23                          M                        3
# 2              1988-05-26                          M                        3
# 3              1986-04-19                          M                        3
# 4              2009-12-21                          F                        3
#
#   paciente_racaCor_valor paciente_endereco_coIbgeMunicipio  \
# 0                AMARELA                            120040
# 1                  PARDA                            120050
# 2                  PARDA                            120040
# 3                  PARDA                            120040
# 4                  PARDA                            120020
#
#   paciente_endereco_coPais paciente_endereco_nmMunicipio  ...  \
# 0                       10                    RIO BRANCO  ...
# 1                       10                SENA MADUREIRA  ...
# 2                       10                    RIO BRANCO  ...
# 3                       10                    RIO BRANCO  ...
# 4                       10               CRUZEIRO DO SUL  ...
#
#   vacina_categoria_codigo      vacina_categoria_nome vacina_lote  \
# 0                     2.0               Faixa Etária  217VCD228Z
# 1                     2.0               Faixa Etária      FF8848
# 2                     2.0               Faixa Etária      FH4750
# 3                     8.0  Trabalhadores da Educação      FJ2594
# 4                     2.0               Faixa Etária      FF8848
#
#   vacina_fabricante_nome  vacina_fabricante_referencia vacina_dataAplicacao  \
# 0    ASTRAZENECA/FIOCRUZ   Organization/33781055000135           2021-09-01
# 1                 PFIZER   Organization/00394544000851           2021-11-10
# 2                 PFIZER            Organization/28290           2021-11-24
# 3                 PFIZER            Organization/28290           2021-12-20
# 4                 PFIZER            Organization/28290           2022-02-24
#
#   vacina_descricao_dose  vacina_codigo  \
# 0               2ª Dose             85
# 1               2ª Dose             87
# 2               2ª Dose             87
# 3               Reforço             87
# 4               2ª Dose             87
#
#                                  vacina_nome sistema_origem
# 0  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
# 1                COVID-19 PFIZER - COMIRNATY       Novo PNI
# 2                COVID-19 PFIZER - COMIRNATY       Novo PNI
# 3                COVID-19 PFIZER - COMIRNATY       Novo PNI
# 4                COVID-19 PFIZER - COMIRNATY       Novo PNI
#
# [5 rows x 32 columns]

# %%
vacAcre.head()
# Out:
#                                  document_id  \
# 0  2129beab-a813-412e-adf1-02878b427b81-i0b0
# 1  5fb3b4b8-1035-489c-bcfb-2eef4a3dbf6e-i0b0
# 2  406d10ac-6eea-4889-bd70-08f5cfc91698-i0b0
# 3  5fc5171d-fcca-4777-9c38-7009357bf486-i0b0
# 4  9c40bdcd-78df-42a2-baba-df6b6d8d2b40-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  7f22d009fc79c0e65a1a4c51542da4bbb88fb51bb631a9...              43
# 1  f04fa961fb64257ae4ab24f5ee31c22534a68c0bd4bf95...              14
# 2  163928d20b579463c9313f1d58ce575cdd585f8afa3c1a...              33
# 3  0abd1dfae4881cfa25c8cd985381ee416755b38f646d4b...              35
# 4  ed43984d7c86535e9493f652ae24f5c13049b6d497766e...              12
#
#   paciente_dataNascimento paciente_enumSexoBiologico  paciente_racaCor_codigo  \
# 0              1978-02-15                          F                        4
# 1              2007-07-23                          M                        3
# 2              1988-05-26                          M                        3
# 3              1986-04-19                          M                        3
# 4              2009-12-21                          F                        3
#
#   paciente_racaCor_valor paciente_endereco_coIbgeMunicipio  \
# 0                AMARELA                            120040
# 1                  PARDA                            120050
# 2                  PARDA                            120040
# 3                  PARDA                            120040
# 4                  PARDA                            120020
#
#   paciente_endereco_coPais paciente_endereco_nmMunicipio  ...  \
# 0                       10                    RIO BRANCO  ...
# 1                       10                SENA MADUREIRA  ...
# 2                       10                    RIO BRANCO  ...
# 3                       10                    RIO BRANCO  ...
# 4                       10               CRUZEIRO DO SUL  ...
#
#   vacina_categoria_codigo      vacina_categoria_nome vacina_lote  \
# 0                     2.0               Faixa Etária  217VCD228Z
# 1                     2.0               Faixa Etária      FF8848
# 2                     2.0               Faixa Etária      FH4750
# 3                     8.0  Trabalhadores da Educação      FJ2594
# 4                     2.0               Faixa Etária      FF8848
#
#   vacina_fabricante_nome  vacina_fabricante_referencia vacina_dataAplicacao  \
# 0    ASTRAZENECA/FIOCRUZ   Organization/33781055000135           2021-09-01
# 1                 PFIZER   Organization/00394544000851           2021-11-10
# 2                 PFIZER            Organization/28290           2021-11-24
# 3                 PFIZER            Organization/28290           2021-12-20
# 4                 PFIZER            Organization/28290           2022-02-24
#
#   vacina_descricao_dose  vacina_codigo  \
# 0               2ª Dose             85
# 1               2ª Dose             87
# 2               2ª Dose             87
# 3               Reforço             87
# 4               2ª Dose             87
#
#                                  vacina_nome sistema_origem
# 0  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
# 1                COVID-19 PFIZER - COMIRNATY       Novo PNI
# 2                COVID-19 PFIZER - COMIRNATY       Novo PNI
# 3                COVID-19 PFIZER - COMIRNATY       Novo PNI
# 4                COVID-19 PFIZER - COMIRNATY       Novo PNI
#
# [5 rows x 32 columns]

# %%
vacAcre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351187 entries, 0 to 351186
# Data columns (total 32 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   document_id                               351187 non-null  object
#  1   paciente_id                               351187 non-null  object
#  2   paciente_idade                            351187 non-null  int64
#  3   paciente_dataNascimento                   351187 non-null  object
#  4   paciente_enumSexoBiologico                351187 non-null  object
#  5   paciente_racaCor_codigo                   351187 non-null  int64
#  6   paciente_racaCor_valor                    351187 non-null  object
#  7   paciente_endereco_coIbgeMunicipio         349042 non-null  object
#  8   paciente_endereco_coPais                  349046 non-null  object
#  9   paciente_endereco_nmMunicipio             349045 non-null  object
#  10  paciente_endereco_nmPais                  349046 non-null  object
#  11  paciente_endereco_uf                      349042 non-null  object
#  12  paciente_endereco_cep                     316398 non-null  object
#  13  paciente_nacionalidade_enumNacionalidade  351055 non-null  object
#  14  estabelecimento_valor                     351187 non-null  int64
#  15  estabelecimento_razaoSocial               351187 non-null  object
#  16  estalecimento_noFantasia                  351187 non-null  object
#  17  estabelecimento_municipio_codigo          351187 non-null  int64
#  18  estabelecimento_municipio_nome            351187 non-null  object
#  19  estabelecimento_uf                        351187 non-null  object
#  20  vacina_grupoAtendimento_codigo            351174 non-null  float64
#  21  vacina_grupoAtendimento_nome              350208 non-null  object
#  22  vacina_categoria_codigo                   330791 non-null  float64
#  23  vacina_categoria_nome                     330791 non-null  object
#  24  vacina_lote                               351187 non-null  object
#  25  vacina_fabricante_nome                    351187 non-null  object
#  26  vacina_fabricante_referencia              349011 non-null  object
#  27  vacina_dataAplicacao                      351187 non-null  object
#  28  vacina_descricao_dose                     351187 non-null  object
#  29  vacina_codigo                             351187 non-null  int64
#  30  vacina_nome                               351178 non-null  object
#  31  sistema_origem                            350788 non-null  object
# dtypes: float64(2), int64(5), object(25)
# memory usage: 85.7+ MB

# %%
vacAcre.shape[0]
# Out:
# 351187

# %%
# 2) 
vacAcre['paciente_id'].nunique()
# Out:
# 293235

# %%
# 3) 
vacAcre.loc[vacAcre['vacina_descricao_dose'] == '1ª Dose' , 'paciente_id'].nunique()
# Out:
# 139499

# %%
# 3) solução alternativa
vacAcre_1dose = vacAcre[vacAcre['vacina_descricao_dose'] == '1ª Dose'].copy()
vacAcre_1dose['paciente_id'].nunique()
# Out:
# 139499

# %%
# 4) 
vacAcre.loc[vacAcre['paciente_idade'] < 18, 'paciente_id'].nunique()
# Out:
# 55452

# %%
# 5)
vacAcre['estalecimento_noFantasia'].nunique()
# Out:
# 147

# %% [markdown]
# ## 4) Vacinação II
# Gere um *DataFrame* que contenha somente os estabelecimentos que aplicaram vcinas a menores de 18 anos. Nesse *DataFrame* devem conter somente os dados dos estabelecimentos, mais uma coluna sendo a quantidade de vacinas que o estabelecimento aplicou a menores de 18 anos.
#
# 1. crie uma cópia do *DataFrame* original, contendo somente os registros de vacinas realizadas a menores de 18 anos.
# 2. crie uma lista das colunas desse *DataFrame* com o atributo de *DataFrame* **.columns()**
# 3. Nesse *DataFrame* faça uma contagem do campo ```vacina_categoria_nome```.
# 4. a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, faça uma lista com esses valores.
# 5. usando o método *.loc*, selecione somente essas variáveis
# 6. Aplique o método **.drop_duplicates** e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento

# %%
# 1)  crie uma cópia do *DataFrame* original, contendo somente os registros de
# vacinas realizadas a menores de 18 anos. 

vacAcre_copy = vacAcre[vacAcre['paciente_idade'] < 18].copy()
vacAcre_copy.head(5)
# Out:
#                                   document_id  \
# 1   5fb3b4b8-1035-489c-bcfb-2eef4a3dbf6e-i0b0
# 4   9c40bdcd-78df-42a2-baba-df6b6d8d2b40-i0b0
# 8   481b2cda-d77e-425c-8b76-2a358a9abca6-i0b0
# 9   5ff2d85e-abdd-4501-974e-3020766734fe-i0b0
# 23  611d98e1-579c-40e1-a44a-2b2fe3a398b2-i0b0
#
#                                           paciente_id  paciente_idade  \
# 1   f04fa961fb64257ae4ab24f5ee31c22534a68c0bd4bf95...              14
# 4   ed43984d7c86535e9493f652ae24f5c13049b6d497766e...              12
# 8   c886f14732ab0f1dff6f3f1dedb807de836fe831e7721b...              17
# 9   fffcff498609bb25c947b6b4b0a9db3f6d16c979ac7095...              12
# 23  78203040a1fa305e55eba6b65451acccc24b198fb7266e...              12
#
#    paciente_dataNascimento paciente_enumSexoBiologico  \
# 1               2007-07-23                          M
# 4               2009-12-21                          F
# 8               2004-01-04                          F
# 9               2009-10-10                          F
# 23              2009-02-24                          M
#
#     paciente_racaCor_codigo paciente_racaCor_valor  \
# 1                         3                  PARDA
# 4                         3                  PARDA
# 8                         4                AMARELA
# 9                         3                  PARDA
# 23                        3                  PARDA
#
#    paciente_endereco_coIbgeMunicipio paciente_endereco_coPais  \
# 1                             120050                       10
# 4                             120020                       10
# 8                             120050                       10
# 9                             120020                       10
# 23                            120040                       10
#
#    paciente_endereco_nmMunicipio  ... vacina_categoria_codigo  \
# 1                 SENA MADUREIRA  ...                     2.0
# 4                CRUZEIRO DO SUL  ...                     2.0
# 8                 SENA MADUREIRA  ...                   114.0
# 9                CRUZEIRO DO SUL  ...                     2.0
# 23                    RIO BRANCO  ...                     2.0
#
#    vacina_categoria_nome vacina_lote vacina_fabricante_nome  \
# 1           Faixa Etária      FF8848                 PFIZER
# 4           Faixa Etária      FF8848                 PFIZER
# 8                 Outros      FA9096                 PFIZER
# 9           Faixa Etária     31130BA                 PFIZER
# 23          Faixa Etária      FA9096                 PFIZER
#
#     vacina_fabricante_referencia vacina_dataAplicacao vacina_descricao_dose  \
# 1    Organization/00394544000851           2021-11-10               2ª Dose
# 4             Organization/28290           2022-02-24               2ª Dose
# 8    Organization/00394544000851           2021-08-11               1ª Dose
# 9    Organization/00394544000851           2021-10-19               1ª Dose
# 23   Organization/00394544000851           2021-08-13               1ª Dose
#
#     vacina_codigo                  vacina_nome sistema_origem
# 1              87  COVID-19 PFIZER - COMIRNATY       Novo PNI
# 4              87  COVID-19 PFIZER - COMIRNATY       Novo PNI
# 8              87  COVID-19 PFIZER - COMIRNATY       Novo PNI
# 9              87  COVID-19 PFIZER - COMIRNATY       Novo PNI
# 23             87  COVID-19 PFIZER - COMIRNATY       Novo PNI
#
# [5 rows x 32 columns]

# %%
# 2) crie uma lista das colunas desse DataFrame com o atributo de DataFrame .columns()
lista_colunas = list(vacAcre_copy.columns)
lista_colunas
# Out:
# ['document_id',
#  'paciente_id',
#  'paciente_idade',
#  'paciente_dataNascimento',
#  'paciente_enumSexoBiologico',
#  'paciente_racaCor_codigo',
#  'paciente_racaCor_valor',
#  'paciente_endereco_coIbgeMunicipio',
#  'paciente_endereco_coPais',
#  'paciente_endereco_nmMunicipio',
#  'paciente_endereco_nmPais',
#  'paciente_endereco_uf',
#  'paciente_endereco_cep',
#  'paciente_nacionalidade_enumNacionalidade',
#  'estabelecimento_valor',
#  'estabelecimento_razaoSocial',
#  'estalecimento_noFantasia',
#  'estabelecimento_municipio_codigo',
#  'estabelecimento_municipio_nome',
#  'estabelecimento_uf',
#  'vacina_grupoAtendimento_codigo',
#  'vacina_grupoAtendimento_nome',
#  'vacina_categoria_codigo',
#  'vacina_categoria_nome',
#  'vacina_lote',
#  'vacina_fabricante_nome',
#  'vacina_fabricante_referencia',
#  'vacina_dataAplicacao',
#  'vacina_descricao_dose',
#  'vacina_codigo',
#  'vacina_nome',
#  'sistema_origem']

# %%
# 3) Nesse DataFrame faça uma contagem do campo vacina_categoria_nome.

vacAcre_copy['vacina_categoria_nome'].value_counts()
# Out:
# Faixa Etária                                      34832
# Outros                                             3701
# Povos Indígenas                                    1994
# Povos e Comunidades Tradicionais                    616
# Trabalhadores de Saúde                              238
# População Privada de Liberdade                       50
# Comorbidades                                         39
# Gestantes                                            23
# Pessoas com Deficiência                               4
# Pessoas Institucionalizadas                           3
# Pessoas de 60 anos ou mais institucionalizadas        1
# Trabalhadores da Educação                             1
# Name: vacina_categoria_nome, dtype: int64

# %%
# 4) a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, 
#    faça uma lista com esses valores

lista_estabelecimento = []
for i in lista_colunas:
    if 'esta'in i and 'cimento'in i:
        lista_estabelecimento.append(i)
lista_estabelecimento
# Out:
# ['estabelecimento_valor',
#  'estabelecimento_razaoSocial',
#  'estalecimento_noFantasia',
#  'estabelecimento_municipio_codigo',
#  'estabelecimento_municipio_nome',
#  'estabelecimento_uf']

# %%
# 5) usando o método .loc, selecione somente essas variáveis

vacAcre_copy.loc[vacAcre_copy['paciente_idade'] < 18, lista_estabelecimento]
# Out:
#         estabelecimento_valor              estabelecimento_razaoSocial  \
# 1                     2002566   PREFEITURA MUNICIPAL DE SENA MADUREIRA
# 4                     7232489            PREFEITURA MUNICIPAL DE SAUDE
# 8                     5981891  PREFEITURA MUNICIIPAL DE SENA MADUREIRA
# 9                     2000369  PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 23                    6917291       PREFEITURA MUNICIPAL DE RIO BRANCO
# ...                       ...                                      ...
# 351161                2000342  PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 351165                6917291       PREFEITURA MUNICIPAL DE RIO BRANCO
# 351166                3006166       PREFEITURA MUNICIPAL DE ACRELANDIA
# 351171                7232489            PREFEITURA MUNICIPAL DE SAUDE
# 351180                 468363                            REDE DE FRIOS
#
#                                  estalecimento_noFantasia  \
# 1           UNIDADE BASICA DE SAUDE LAURO FONTES DA SILVA
# 4       UNIDADE DE SAUDE DA FAMILIA FRANCISCO SOUZA DO...
# 8                        UNIDADE BASICA DE SAUDE MODULO I
# 9       UNIDADE DA SAUDE DA FAM JOSE MATHEUS ARNALDO D...
# 23      DEPARTAMENTO DE VIGILANCIA EPIDEMIOLOGICA E AM...
# ...                                                   ...
# 351161          UNIDADE DE SAUDE DA FAMILIA ABEL PINHEIRO
# 351165  DEPARTAMENTO DE VIGILANCIA EPIDEMIOLOGICA E AM...
# 351166  UNIDADE DE SAUDE DA FAMILIA NORTON VITORINO BOHEN
# 351171  UNIDADE DE SAUDE DA FAMILIA FRANCISCO SOUZA DO...
# 351180                                      REDE DE FRIOS
#
#         estabelecimento_municipio_codigo estabelecimento_municipio_nome  \
# 1                                 120050                 SENA MADUREIRA
# 4                                 120020                CRUZEIRO DO SUL
# 8                                 120050                 SENA MADUREIRA
# 9                                 120020                CRUZEIRO DO SUL
# 23                                120040                     RIO BRANCO
# ...                                  ...                            ...
# 351161                            120020                CRUZEIRO DO SUL
# 351165                            120040                     RIO BRANCO
# 351166                            120001                     ACRELANDIA
# 351171                            120020                CRUZEIRO DO SUL
# 351180                            120033                    MANCIO LIMA
#
#        estabelecimento_uf
# 1                      AC
# 4                      AC
# 8                      AC
# 9                      AC
# 23                     AC
# ...                   ...
# 351161                 AC
# 351165                 AC
# 351166                 AC
# 351171                 AC
# 351180                 AC
#
# [61437 rows x 6 columns]
