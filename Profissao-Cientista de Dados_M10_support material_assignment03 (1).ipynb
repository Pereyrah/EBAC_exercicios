# %% [markdown]
# # Módulo 10 tarefa 03
# Considere a mesma base de dados utilizada na tarefa 1 ```previsao_de_renda.csv```.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# Carregando a base CVC
df = pd.read_csv('previsao_de_renda.csv')
df = df.drop(['Unnamed: 0', 'index'], axis=1)
df.head()
# Out:
#      data_ref sexo  posse_de_veiculo  posse_de_imovel  qtd_filhos  \
# 0  2015-01-01    F             False             True           1
# 1  2015-01-01    M              True             True           0
# 2  2015-01-01    M              True             True           2
# 3  2015-01-01    F              True            False           0
# 4  2015-01-01    M             False            False           0
#
#     tipo_renda           educacao estado_civil tipo_residencia  idade  \
# 0  Assalariado         Secundário       Casado            Casa     36
# 1   Empresário         Secundário       Casado            Casa     42
# 2  Assalariado  Superior completo       Casado            Casa     31
# 3   Empresário         Secundário       Casado            Casa     50
# 4  Assalariado         Secundário       Casado            Casa     52
#
#    tempo_emprego  qt_pessoas_residencia    mau    renda
# 0       3.575342                    3.0  False  3369.24
# ...

# %%
# verificando os tipos de dados das variáveis
df.dtypes
# Out:
# data_ref                  object
# sexo                      object
# posse_de_veiculo            bool
# posse_de_imovel             bool
# qtd_filhos                 int64
# tipo_renda                object
# educacao                  object
# estado_civil              object
# tipo_residencia           object
# idade                      int64
# tempo_emprego            float64
# qt_pessoas_residencia    float64
# mau                         bool
# renda                    float64
# dtype: object

# %%
# Alterando data_ref (object) para datetime
df['data_ref'] = pd.to_datetime(df['data_ref'])
df.dtypes
# Out:
# data_ref                 datetime64[ns]
# sexo                             object
# posse_de_veiculo                   bool
# posse_de_imovel                    bool
# qtd_filhos                        int64
# tipo_renda                       object
# educacao                         object
# estado_civil                     object
# tipo_residencia                  object
# idade                             int64
# tempo_emprego                   float64
# qt_pessoas_residencia           float64
# mau                                bool
# renda                           float64
# dtype: object

# %%
# Verificando a quantidade de missings
df.isnull().sum()
# Out:
# data_ref                    0
# sexo                        0
# posse_de_veiculo            0
# posse_de_imovel             0
# qtd_filhos                  0
# tipo_renda                  0
# educacao                    0
# estado_civil                0
# tipo_residencia             0
# idade                       0
# tempo_emprego            2534
# qt_pessoas_residencia       0
# mau                         0
# renda                       0
# dtype: int64

# %% [markdown]
# 1) Construa um gráfico de barras para avaliar a distribuição das variáveis qualitativas no tempo. Você acha que houve alguma alteração importante a ser investigada?

# %%
# sexo
ax = sns.countplot(
    data=df,
    x='data_ref',
    hue='sexo'
)

tick_labs = df['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(df['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=90)
title = ax.set_title('Sexo')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
# Tipo de renda

ax = sns.countplot(
    data=df,
    x='data_ref',
    hue='tipo_renda'
)

tick_labs = df['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(df['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=90)
title = ax.set_title('Tipo de Renda')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
# Educação

ax = sns.countplot(
    data=df,
    x='data_ref',
    hue='educacao'
)

tick_labs = df['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(df['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=90)
title = ax.set_title('Educação')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
# Estado Civil
ax = sns.countplot(
    data=df,
    x='data_ref',
    hue='estado_civil'
)

tick_labs = df['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(df['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=90)
title = ax.set_title('Estado Civil')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
# tipo_residencia
ax = sns.countplot(
    data=df,
    x='data_ref',
    hue='tipo_residencia'
)

tick_labs = df['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(df['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=90)
title = ax.set_title('Tipo de Residência')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
# posse de veiculo
ax = sns.countplot(
    data=df,
    x='data_ref',
    hue='posse_de_veiculo'
)

tick_labs = df['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(df['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=90)
title = ax.set_title('Posse de Veiculo')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
# Posse de imovel
ax = sns.countplot(
    data=df,
    x='data_ref',
    hue='posse_de_imovel'
)

tick_labs = df['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(df['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=90)
title = ax.set_title('Posse de Imóvel')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
ax = sns.countplot(
    data=df,
    x='data_ref',
    hue='mau'
)

tick_labs = df['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(df['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=90)
title = ax.set_title('Mau Pagador')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %% [markdown]
# ## Insights

# %% [markdown]
# . Podemos perceber que as variáveis qualitativas, não possui variações significativas. No entanto a variável Educação teve variação com o tempo. Teve diminuição no "secundário" e aumento no "Superior completo".

# %% [markdown]
# 2) Para cada variável qualitativa, construa um gráfico mostrando as médias de cada nível da variável no tempo e avalie a estabilidade. Houve alguma alteração importante? Você acha que se pode utilizar essas variáveis em uma modelagem?

# %%
# y=renda, x=data_ref, hue=posse_de_imovel
ax = sns.pointplot(
    data=df,
    x='data_ref',
    y='renda',
    hue='posse_de_imovel',
    dodge=True,
    ci=95
)

plt.legend(loc='lower center', bbox_to_anchor=(0.5, -.30), ncol=3)

tick_labs = df['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(df['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=90)
title = ax.set_title('Posse de Imóvel')

plt.legend(loc='lower center', bbox_to_anchor=(0.5, -.50), ncol=3)

# %%
# y=renda, x=data_ref, hue=posse_de_veiculo
ax = sns.pointplot(
    data=df,
    x='data_ref',
    y='renda',
    hue='posse_de_veiculo',
    dodge=True,
    ci=95
)

plt.legend(loc='lower center', bbox_to_anchor=(0.5, -.30), ncol=3)

tick_labs = df['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(df['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=90)
title = ax.set_title('Posse de Veículo')

plt.legend(loc='lower center', bbox_to_anchor=(0.5, -.50), ncol=3)

# %%
# y=renda, x=data_ref, hue=tipo_residencia
ax = sns.pointplot(
    data=df,
    x='data_ref',
    y='renda',
    hue='tipo_residencia',
    dodge=True,
    ci=95
)

plt.legend(loc='lower center', bbox_to_anchor=(0.5, -.30), ncol=3)

tick_labs = df['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(df['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=90)
title = ax.set_title('Tipo de Residência')

plt.legend(loc='lower center', bbox_to_anchor=(0.5, -.50), ncol=3)

# %%
# y=renda, x=data_ref, hue=educacao
ax = sns.pointplot(
    data=df,
    x='data_ref',
    y='renda',
    hue='educacao',
    dodge=True,
    ci=95
)

plt.legend(loc='lower center', bbox_to_anchor=(0.5, -.30), ncol=3)

tick_labs = df['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(df['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=90)
title = ax.set_title('Educação')

plt.legend(loc='lower center', bbox_to_anchor=(0.5, -.50), ncol=3)

# %%
# y=renda, x=data_ref, hue=tipo_renda
ax = sns.pointplot(
    data=df,
    x='data_ref',
    y='renda',
    hue='tipo_renda',
    dodge=True,
    ci=95
)

plt.legend(loc='lower center', bbox_to_anchor=(0.5, -.30), ncol=3)

tick_labs = df['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(df['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=90)
title = ax.set_title('Tipo de Renda')

plt.legend(loc='lower center', bbox_to_anchor=(0.5, -.50), ncol=3)

# %%
# y=qtd_filhos, x=data_ref, hue=sexo
ax = sns.pointplot(
    data=df,
    x='data_ref',
    y='qtd_filhos',
    hue='sexo',
    dodge=True,
    ci=95
)

plt.legend(loc='lower center', bbox_to_anchor=(0.5, -.30), ncol=3)

tick_labs = df['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(df['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=90)
title = ax.set_title('Sexo X Quantidade de filhos')

plt.legend(loc='lower center', bbox_to_anchor=(0.5, -.50), ncol=3)

# %%
# y=posse_de_imovel, x=data_ref, hue=sexo
ax = sns.pointplot(
    data=df,
    x='data_ref',
    y='posse_de_imovel',
    hue='sexo',
    dodge=True,
    ci=95
)

plt.legend(loc='lower center', bbox_to_anchor=(0.5, -.30), ncol=3)

tick_labs = df['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(df['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=90)
title = ax.set_title('Sexo X Posse de imóvel')

plt.legend(loc='lower center', bbox_to_anchor=(0.5, -.50), ncol=3)

# %%
# y=posse_de_veiculo, x=data_ref, hue=sexo
ax = sns.pointplot(
    data=df,
    x='data_ref',
    y='posse_de_veiculo',
    hue='sexo',
    dodge=True,
    ci=95
)

plt.legend(loc='lower center', bbox_to_anchor=(0.5, -.30), ncol=3)

tick_labs = df['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(df['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=90)
title = ax.set_title('Sexo X Posse de veículo')

plt.legend(loc='lower center', bbox_to_anchor=(0.5, -.50), ncol=3)

# %%
# y=idade, x=data_ref, hue=sexo
ax = sns.pointplot(
    data=df,
    x='data_ref',
    y='idade',
    hue='sexo',
    dodge=True,
    ci=95
)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.30),ncol = 3)

tick_labs = df['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(df['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=90)
title = ax.set_title('Sexo X Idade')

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.50),ncol = 3)

# %% [markdown]
# ### Insight
#
# . Analisando os gráficos, duas variáveis (renda x posse de veículo e renda X educação), possuem diferença ao longo do tempo, entretanto, aparentemente não são valores tão discrepantes a serem considerados.
